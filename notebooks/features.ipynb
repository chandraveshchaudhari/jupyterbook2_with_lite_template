# %% [markdown]
# # Feature Showcase and Subsections
#
# <a href="https://colab.research.google.com/github/chandraveshchaudhari/jupyterbook2_with_lite_template/blob/main/notebooks/features.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab" /></a>
#
#
# This notebook demonstrates common Jupyter Book content patterns.

# %% [markdown]
# ## HTML Rendering in markdown
#
# You can use inline HTML, standard Markdown and tables
#
# <section style="max-width:680px;margin:12px 0;padding:18px;border-radius:14px;border:1px solid #d8dee9;background:linear-gradient(135deg,#f7fbff,#f0fff4);box-shadow:0 8px 24px rgba(15,23,42,0.08);font-family:Segoe UI,Helvetica,Arial,sans-serif;">
#   <h4 style="margin:0 0 8px 0;color:#0f172a;">Course Progress Snapshot</h4>
#   <p style="margin:0 0 12px 0;color:#334155;line-height:1.5;">A compact status panel built with pure HTML that renders directly inside markdown.</p>
#   <div style="display:flex;gap:10px;flex-wrap:wrap;margin-bottom:12px;">
#     <span style="background:#e0f2fe;color:#075985;padding:4px 10px;border-radius:999px;font-size:12px;font-weight:600;">Module 1 Complete</span>
#     <span style="background:#dcfce7;color:#166534;padding:4px 10px;border-radius:999px;font-size:12px;font-weight:600;">Lab Ready</span>
#     <span style="background:#fef3c7;color:#92400e;padding:4px 10px;border-radius:999px;font-size:12px;font-weight:600;">Quiz Pending</span>
#   </div>
#   <div style="height:10px;background:#e2e8f0;border-radius:999px;overflow:hidden;">
#     <div style="width:72%;height:100%;background:linear-gradient(90deg,#0ea5e9,#22c55e);"></div>
#   </div>
#   <p style="margin:10px 0 0 0;font-size:12px;color:#475569;">Overall completion: <strong>72%</strong></p>
# </section>

# %% [markdown]
# ## Tables and Structured Data
#
# ### Basic Markdown Table
#
# | Left Align | Center Align | Right Align |
# |:-----------|:------------:|------------:|
# | Text       | Text         | Text        |
# | Data       | Data         | Data        |
#
# ### Showcase Table
#
# | Feature | Category | Description |
# |---|---|---|
# | MyST Markdown | Reusable | Create clean, reusable documentation pages |
# | Notebook execution | Reproducible | Keep outputs consistent in published docs |
# | JupyterLite + Pyodide | Interactive | Run Python directly in browser without local kernel |
#
# Tip: Standard markdown tables render in both the notebook editor and the built Jupyter Book site.

# %% [markdown]
# ## LaTeX and Math Showcase
#
# Inline equation: $e^{i\pi} + 1 = 0$
#
# Required inline math example: $E = mc^2$
#
# Block equation:
#
# $$
# \int_0^1 x^2 \, dx
# $$
#
# Math notation should render both in the notebook and in the built Jupyter Book website. Advanced equation numbering and cross-references are website-oriented features.

# %% [markdown]
# ## Python code Example

# %%
# normal code cell
print('Hello from JupyterLite-ready markdown!')
for i in range(3):
    print(f'Step {i}')
# Out:
# Hello from JupyterLite-ready markdown!
# Step 0
# Step 1
# Step 2

# %%
# code cell without output
print('Hello from JupyterLite-ready markdown!')
for i in range(3):
    print(f'Step {i}')

# %%
# Visualization example
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x, y, marker='o')
plt.title('Sample Plot')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data
x = np.linspace(0, 10, 200)
y1 = np.sin(x)
y2 = np.cos(x)

# Create plot
plt.figure(figsize=(8,5))

plt.plot(x, y1, label="Sine Wave")
plt.plot(x, y2, label="Cosine Wave")

plt.title("Matplotlib Example (Static JupyterBook Friendly)")
plt.xlabel("X values")
plt.ylabel("Y values")

plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# ## Interactive Plotly Charts (JupyterLite / Pyodide)
#
# Plotly charts are fully interactive in JupyterLite. Click ⚡ in the toolbar to activate in-browser execution, then run the cells below.
#
# > **Note:** The first `%pip install plotly` call is needed only once per JupyterLite session.

# %%
# Install plotly (required in JupyterLite/Pyodide; harmless in Colab/Local)
# %pip install plotly

# %%
import plotly.express as px

# Interactive bar chart — hover, zoom, and download via toolbar
fig = px.bar(
    x=['Python', 'Jupyter', 'Plotly', 'MyST', 'JupyterLite'],
    y=[95, 88, 82, 75, 91],
    labels={'x': 'Tool', 'y': 'Popularity Score'},
    title='Tool Popularity — Interactive Bar Chart',
    color_discrete_sequence=['#3b82f6']
)
fig.update_layout(margin=dict(t=50, b=40))
fig.show()

# %%
import plotly.graph_objects as go
import math

# Interactive sine/cosine — scroll to zoom, drag to pan
x = [i * 0.1 for i in range(100)]
fig = go.Figure()
fig.add_trace(go.Scatter(x=x, y=[math.sin(v) for v in x], name='sin(x)', line=dict(color='#3b82f6')))
fig.add_trace(go.Scatter(x=x, y=[math.cos(v) for v in x], name='cos(x)', line=dict(color='#f59e0b')))
fig.update_layout(
    title='Sine & Cosine — Interactive Line Chart',
    xaxis_title='x', yaxis_title='y',
    margin=dict(t=50, b=40)
)
fig.show()

# %% [markdown]
# ## Native JupyterBook v2 (MyST) Features
#
# JupyterBook v2 provides these capabilities **natively in `myst.yml`** — no custom Python scripts needed.
#
# ---
#
# ### In-Browser Execution with JupyterLite (Thebe)
#
# Setting `jupyter: {lite: true}` in `myst.yml` adds a **Launch** button to every page.
# Clicking it opens the notebook directly in **JupyterLite** in the browser — no server, no installation.
#
# ```yaml
# # myst.yml
# project:
#   jupyter:
#     lite: true
# ```
#
#
# Any standard notebook code cell in your `.ipynb` files becomes runnable in-browser automatically via the launch button.
#
# ---
#
# ### Binder Launch Buttons
#
# To also add a Binder launch button, extend the `jupyter` block:
#
# ```yaml
# # myst.yml
# project:
#   jupyter:
#     lite: true
#     binder:
#       repo: your-github-username/your-repo
#       ref: main
# ```
#
# ---
#
# ### auto_notebook_creation_using_toc.py
#
# The `extensions/auto_notebook_creation_using_toc.py` script scaffolds placeholder `.ipynb` files
# from the `project.toc` entries in `myst.yml`. Run it once when setting up a new book:
#
# ```bash
# python extensions/auto_notebook_creation_using_toc.py
# ```
#
# For **auto-discovery** of all existing files in a folder, MyST also supports `pattern:` globs in the TOC:
#
# ```yaml
# toc:
#   - file: intro
#   - title: My Chapter
#     children:
#       - pattern: 'notebooks/*.ipynb'
# ```

# %% [markdown]
# ## Images and Figures
#
# Standard notebook-friendly image example:
#
# <img src="https://github.com/chandraveshchaudhari/chandraveshchaudhari/blob/e5c0993aacb917c625dd4b47afeeb959a006191a/data/logo.png?raw=true" alt="JupyterBook Logo" style="width:30%;" />
#
# Figure: Jupyter Book logo used as a stable documentation preview image.
#
#
# ### Demo Video
#
# <iframe width="560" height="315" src="https://www.youtube.com/embed/3MUSteQFGq8?si=TqqCnl9WjnIXkTEM" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
